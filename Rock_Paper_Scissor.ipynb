# %%
import random
import sys

# %%
Rock = 1
Paper = 2
Scissor = 3
print("Welcome to Rock-Paper-Scisson Game")
print('Winning rules of the game ROCK PAPER SCISSORS are:\n'
      + "Rock vs Paper -> Paper wins \n"
      + "Rock vs Scissors -> Rock wins \n"
      + "Paper vs Scissors -> Scissors wins \n")
while True:
    print("Enter 1 for Rock, 2 for Paper and 3 for Scissor")
    user_choice = int(input())
    while user_choice > 3 or user_choice < 1:
        user_choice = int(input('Enter a valid choice please: '))
    print("you have selected",user_choice)
    print("Now it's Computer's Turn...")
    comp_choice = random.randint(1, 3)
    print("Computer have selected",comp_choice)
    
    if user_choice == 1:
        choice_name = 'Rock'
    elif user_choice == 2:
        choice_name = 'Paper'
    else:
        choice_name = 'Scissors'

    if comp_choice == 1:
        comp_choice_name = 'Rock'
    elif comp_choice == 2:
        comp_choice_name = 'Paper'
    else:
        comp_choice_name = 'Scissors'
        
    if user_choice == comp_choice:
        result = "DRAW"
    elif (user_choice == 1 and comp_choice == 2) or (user_choice == 2 and comp_choice == 1):
        result = "PAPER"
    elif (user_choice == 1 and comp_choice == 3) or (user_choice == 3 and comp_choice == 1):
        result = "ROCK"
    elif (user_choice == 2 and comp_choice == 3) or (user_choice == 3 and comp_choice == 2):
        result = "SCISSOR"
    
    if result == "DRAW":
        print(user_choice,"vs",comp_choice,"It is a tie")
    elif result == choice_name:
        print(user_choice,"vs",comp_choice,"User wins")
    else:
        print(user_choice,"vs",comp_choice,"Computer wins")
    
    print("Do you want to play again> (Y/N):")
    ans = input().lower()
    if ans == 'n':
        break
print("Thanks for playing")
# Out:
# Welcome to Rock-Paper-Scisson Game
# Winning rules of the game ROCK PAPER SCISSORS are:
# Rock vs Paper -> Paper wins
# Rock vs Scissors -> Rock wins
# Paper vs Scissors -> Scissors wins
#
# Enter 1 for Rock, 2 for Paper and 3 for Scissor
#  1
# you have selected 1
# Now it's Computer's Turn...
# Computer have selected 3
# 1 vs 3 Computer wins
# Do you want to play again> (Y/N):
#  y
# Enter 1 for Rock, 2 for Paper and 3 for Scissor
#  2
# you have selected 2
# Now it's Computer's Turn...
# Computer have selected 3
# 2 vs 3 Computer wins
# Do you want to play again> (Y/N):
#  y
# Enter 1 for Rock, 2 for Paper and 3 for Scissor
#  3
# you have selected 3
# Now it's Computer's Turn...
# Computer have selected 2
# 3 vs 2 Computer wins
# Do you want to play again> (Y/N):
#  y
# Enter 1 for Rock, 2 for Paper and 3 for Scissor
#  1
# you have selected 1
# Now it's Computer's Turn...
# Computer have selected 2
# 1 vs 2 Computer wins
# Do you want to play again> (Y/N):
#  y
# ...
